# %% [markdown]
# # Import

# %%
from RRModel import RRModel
import warnings
warnings.filterwarnings('ignore')
class Foo:
    pass

# %% [markdown]
# # Experian

# %%
myInput = Foo()
# The above is not important, just follow the format.
model_file ="platform" # Use train/model0 file

# %% [markdown]
# ## CRF

# %%
myInput.machineLearningEngine = 'CRF' # Calibrated Random Forest

# %%
myInput.output_horizon = 1 # Predict PD 3 years later
model = RRModel(myInput, model_file=model_file)
model.train(save=False)
# Out:
# Samples of default companies for machine learning core:  2995
# The MAEs of the model1, the naive method in the training set are [0.1670674423055948, 0.23797494294644747]
# The MAEs of the model1, the naive method in the testing set are [0.16879002782776362, 0.23814207860371867]
# The MAEs of the my_model, the naive method in the training set are [0.16648595481364428, 0.23713853960315814]
# The MAEs of the my_model, the naive method in the testing set are [0.1713414881399529, 0.245757532880181]
# Training Completed!
# (<MachineLearningBasedModels.ML_models.CalibratedRandomForestC at 0x121ee7940>,
#  <RRModel.RRDataClass at 0x1255b1cf8>)

# %%
myInput.output_horizon = 2 # Predict PD 3 years later
model = RRModel(myInput, model_file=model_file)
model.train(save=False)
# Out:
# Samples of default companies for machine learning core:  2995
# The MAEs of the model1, the naive method in the training set are [0.18922864970645675, 0.2365325005655632]
# The MAEs of the model1, the naive method in the testing set are [0.19130517649847334, 0.24388606983924782]
# The MAEs of the my_model, the naive method in the training set are [0.1894647071432618, 0.23725965488159403]
# The MAEs of the my_model, the naive method in the testing set are [0.19545381968721506, 0.24451416277133323]
# (<MachineLearningBasedModels.ML_models.CalibratedRandomForestC at 0x12296a550>,
#  <RRModel.RRDataClass at 0x120652320>)
# Training Completed!

# %%
myInput.output_horizon = 3 # Predict PD 3 years later
model = RRModel(myInput, model_file=model_file)
model.train(save=False)
# Out:
# Samples of default companies for machine learning core:  2995
# The MAEs of the model1, the naive method in the training set are [0.19646877996927922, 0.2365799855864465]
# The MAEs of the model1, the naive method in the testing set are [0.21010044526263882, 0.24333111049434059]
# The MAEs of the my_model, the naive method in the training set are [0.20008222613852672, 0.23887161617712954]
# The MAEs of the my_model, the naive method in the testing set are [0.18596483398250507, 0.22944103272998248]
# Training Completed!
# (<MachineLearningBasedModels.ML_models.CalibratedRandomForestC at 0x1212dd898>,
#  <RRModel.RRDataClass at 0x10ad9c2b0>)

# %%
myInput.output_horizon = 4 # Predict PD 3 years later
model = RRModel(myInput, model_file=model_file)
model.train(save=False)
# Out:
# Samples of default companies for machine learning core:  2995
# The MAEs of the model1, the naive method in the training set are [0.20643772196594495, 0.23819815194259944]
# The MAEs of the model1, the naive method in the testing set are [0.21507019243054737, 0.23664113161774988]
# The MAEs of the my_model, the naive method in the training set are [0.2085409779905995, 0.2397197411677095]
# The MAEs of the my_model, the naive method in the testing set are [0.2003971217229906, 0.22086923645580817]
# Training Completed!
# (<MachineLearningBasedModels.ML_models.CalibratedRandomForestC at 0x121f0f1d0>,
#  <RRModel.RRDataClass at 0x121754e80>)
