# %% [markdown]
# # Import

# %%
from PDModel import PDModel
import warnings
warnings.filterwarnings('ignore')
class Foo:
    pass

# %% [markdown]
# # platform

# %%
myInput = Foo()
modelFile ="platform" # Use train/model0 file

# %% [markdown]
# # CRF

# %%
myInput.machineLearningEngine = 'CRF' # Calibrated Random Forest
myInput.output_horizon = 1 # Predict PD 3 years later
model = PDModel(myInput, model_file=modelFile)
model.train(save=False)
# Out:
# machineLearningEngine:  CRF
# output_horizon:  1
# Samples of default companies for machine learning core:  91
# Samples of active companies for machine learning core:  5365
# AUC-Train:  0.96
# AUC-Test:  0.94
# Training Completed!
# --------------------------------End--------------------------------
# (<MachineLearningBasedModels.ML_models.CalibratedRandomForestC at 0x11fdc2390>,
#  <FinancialProxyCleanData.PD_dataClass.DataClass at 0x115a47ef0>)
